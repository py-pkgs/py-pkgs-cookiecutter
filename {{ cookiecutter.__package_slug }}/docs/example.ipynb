# %% [markdown]
# # Example usage
#
# To use `{{ cookiecutter.__package_slug }}` in a project:

# %%
import {{ cookiecutter.__package_slug }}

print({{ cookiecutter.__package_slug }}.__version__)
